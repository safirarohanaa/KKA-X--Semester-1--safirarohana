# %% [markdown]
# <a href="https://colab.research.google.com/github/safirarohanaa/KKA-X--Semester-1--safirarohana/blob/main/3_aplikasi_kalkulator_sederhana_Rizqi_Safira_Rohana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jari_jari = int(input("Jari jari tabung adalah (cm): "))
tinggi = int(input("Tinggi tabung adalah (cm): "))

volume = 22/7 * jari_jari * jari_jari * tinggi

print(f"\n Volume Tabung yaitu {volume} cm^3")
# Out:
# Jari jari tabung adalah (cm): 5
# Tinggi tabung adalah (cm): 5
#
#  Volume Tabung yaitu 392.85714285714283 cm^3
