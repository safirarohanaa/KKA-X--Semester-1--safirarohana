# %% [markdown]
# <a href="https://colab.research.google.com/github/safirarohanaa/KKA-X--Semester-1--safirarohana/blob/main/Tipe_Variabel_Rizqi_Safira_Rohana_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Jenis-jenis tipe variabel

# %%
a = "Faris"

print(a)
type(a)
# Out:
# Faris
# str

# %%
b = 9.9
print(b)
type(b)
# Out:
# 9.9
# float

# %%
c=0
print(c)
type(c)
# Out:
# 0
# int

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
f = "False"
print(f)
type(f)
# Out:
# False
# str

# %%
g = 9,2
print(g)
type(g)
# Out:
# (9, 2)
# tuple

# %%
type("rendra")
# Out:
# str

# %%
type(-9.1)
# Out:
# float

# %% [markdown]
# #mengubah bentuk variabel

# %%
a = 5
print(a)
type(a)
# Out:
# 5
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 5.0
# float

# %%
b = bool(2)
print(b)
type(b)
# Out:
# True
# bool

# %% [markdown]
# #operator logika

# %%
print(not(5 <= 5))
print (8>7 and 6<5)
print(7<=1 or 2!=2)
print(not(0==1 and 1!=1))
print(not(5<10 or 5<=10))
# Out:
# False
# False
# False
# True
# False

# %% [markdown]
# #operator perbandingan

# %%
print(6 >= 6)
print(8 == 9)
print(8 != 9)
print(8 < 10)
print(8 > 10)
# Out:
# True
# False
# True
# True
# False
